# %%
from MEA_functions import *
from general_parameters import *
from specific_parameters import *

peak_types = ['interictal', 'MUA']
spe = get_param('task3')
drugs = spe.drugs
# Out:
# enter name

# %% [markdown]
# BEFORE STARTING
#
# - Check if you put the images of the slices in the same folder as the h5 files

# %% [markdown]
# To fill the excel file with the right information at the right place

# %%
# %% cache
# fill_info_file()
# pickle_durations()
# Out:
# UsageError: Cell magic `%%` not found.

# %% [markdown]
# We need to manually apply the right layout to get the position of the channels in respect to the image

# %%
# %% cache
# paths = choose_files_from_info()
# for path in paths :
#     # Call function to extract signal and channel names from the h5 file
#     date_time = date_time_from_path(path)
#     %matplotlib qt
#     show_image_tag_channels(date_time, list_channels_all)
# Out:
# UsageError: Cell magic `%%` not found.

# %%
# %% cache
# peak_types =  ['interictal', 'MUA']
# paths, _, conditions = paths_channels_from_info(condition = True)
# #paths, conditions = choose_files_from_info(condition = True)
#
# for num_path, path in enumerate(paths):
#     print(f'-------------------------------- Path {num_path+1} out of {len(paths)} --------------------------------', end = '\r')
#     extract_data(path, conditions[path], peak_types)
# Out:
# UsageError: Cell magic `%%` not found.

# %%
# %% cache
# ID_dict, _ = experiments_dict()
# for peak_type in peak_types :
#     order_channels(ID_dict, peak_type, save_raw = True)
# Out:
# UsageError: Cell magic `%%` not found.

# %%
# %% cache
#
# %matplotlib qt
#
# for peak_type in peak_types :
#     check_recordings(peak_type)
# Out:
# UsageError: Cell magic `%%` not found.

# %%
# %% cache
# run_results(drugs, peak_types, washout=False)
# Out:
# UsageError: Cell magic `%%` not found.

# %%
name_plots = choose_plot_from_folder()

for name_plot in name_plots:
    change_plot_parameters(name_plot)

# %%
#%% cache

# %matplotlib inline

plot_main_results(drugs, washout = False, highlight=True, echo = True)
# Out:
# interictal / terbinafine / baseline : {'exp_ID': 'SH-2022-005_2', 'date_time': '2022-11-22_16-59-14', 'channels': ['J8']}
# interictal / terbinafine / baseline : {'exp_ID': 'SH-2022-005_5', 'date_time': '2022-11-22_19-49-24', 'channels': ['G5']}
# interictal / terbinafine / baseline : {'exp_ID': 'SH-2023-000_1', 'date_time': '2023-01-12_16-01-57', 'channels': ['F4']}
# interictal / terbinafine / baseline : {'exp_ID': 'SH_2023_004_9', 'date_time': '2023-08-08_18-37-08', 'channels': ['E4']}
# interictal / terbinafine / terbinafine : {'exp_ID': 'SH-2022-005_2', 'date_time': '2022-11-22_17-16-27', 'channels': ['J8']}
# interictal / terbinafine / terbinafine : {'exp_ID': 'SH-2022-005_5', 'date_time': '2022-11-22_20-05-08', 'channels': ['G5']}
# interictal / terbinafine / terbinafine : {'exp_ID': 'SH-2023-000_1', 'date_time': '2023-01-12_16-01-58', 'channels': ['F4']}
# ...

# %%
# %% cache
#
# %matplotlib inline
#
# for N_best in range(1,11) :
#
#     run_results(drugs, peak_types, washout=False, N_best=N_best)
#     plot_main_results(drugs, peak_types, washout = False, highlight=True, saving = True, name_fig=f'{N_best}_channels')
# Out:
# UsageError: Cell magic `%%` not found.
